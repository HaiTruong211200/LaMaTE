# %%
# !nvidia-smi
# Out:
# Wed Jan  7 11:44:07 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !ls
# Out:
# sample_data

# %%
# !cd ./MachineTranslation
# Out:
# /bin/bash: line 1: cd: ./MachineTranslation: No such file or directory

# %%
# !git clone -b qwen --single-branch https://github.com/HaiTruong211200/LaMaTE
# Out:
# Cloning into 'LaMaTE'...
# remote: Enumerating objects: 62, done.
# remote: Counting objects: 100% (62/62), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 62 (delta 30), reused 44 (delta 20), pack-reused 0 (from 0)
# Receiving objects: 100% (62/62), 66.84 KiB | 16.71 MiB/s, done.
# Resolving deltas: 100% (30/30), done.

# %%
# !cd LaMaTE/src

# %%
# !ls
# Out:
# LaMaTE	sample_data
