# %%
# !nvidia-smi
# Out:
# Fri Jan  2 03:39:44 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   53C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !ls
# Out:
# sample_data

# %%
# !cd ./MachineTranslation
# Out:
# /bin/bash: line 1: cd: ./MachineTranslation: No such file or directory

# %%
# !git clone -b qwen --single-branch https://github.com/HaiTruong211200/LaMaTE
# Out:
# Cloning into 'LaMaTE'...
# remote: Enumerating objects: 53, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 53 (delta 23), reused 38 (delta 16), pack-reused 0 (from 0)
# Receiving objects: 100% (53/53), 56.08 KiB | 957.00 KiB/s, done.
# Resolving deltas: 100% (23/23), done.
